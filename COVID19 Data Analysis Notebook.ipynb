# %%
# Importing all the modules necessary to create a training set.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('Modules are imported')
# Out:
# Modules are imported

# %%
# Take the csv file and run the dataset into the program by 10 rows
covid19_csv_dataset = pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")
covid19_csv_dataset.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
covid19_csv_dataset.shape
# Out:
# (266, 104)

# %%
# drop two useless sections from the datasets. Latitude and longitude and
# identify that method as df (short for dataframe)
df = covid19_csv_dataset.drop(["Lat", "Long"], axis=1)

# %%
df.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
# This method groups the dataset by Country and Region. df (dataframe)
# is the dataframe without the latitude and longitude columns.

covid19_aggr_dataset = df.groupby("Country/Region").sum()

# %%
# this method display all the data information by 10 rows

covid19_aggr_dataset.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %%
# This method is the shape of the dataset

covid19_aggr_dataset.shape
# Out:
# (187, 100)

# %%
# This method will display data of confirmed cases in a specific location 
# e.g. China

covid19_aggr_dataset.loc["China"]
# Out:
# 1/22/20      548
# 1/23/20      643
# 1/24/20      920
# 1/25/20     1406
# 1/26/20     2075
#            ...
# 4/26/20    83912
# 4/27/20    83918
# 4/28/20    83940
# 4/29/20    83944
# 4/30/20    83956
# Name: China, Length: 100, dtype: int64

# %%
# This method will display data of confirmed cases in a specific location 
# e.g. US

covid19_aggr_dataset.loc["US"]
# Out:
# 1/22/20          1
# 1/23/20          1
# 1/24/20          2
# 1/25/20          2
# 1/26/20          5
#             ...
# 4/26/20     965785
# 4/27/20     988197
# 4/28/20    1012582
# 4/29/20    1039909
# 4/30/20    1069424
# Name: US, Length: 100, dtype: int64

# %%
# This method will display a plotted graph of confirmed cases in a specific location 
# e.g. China and US

covid19_aggr_dataset.loc["China"].plot()
covid19_aggr_dataset.loc["US"].plot()

# %%
# This next method will display a plotted graph of confirmed cases in a specific location 
# e.g. China and US

covid19_aggr_dataset.loc["China"][:3].plot()
covid19_aggr_dataset.loc["US"][:3].plot()

# %%
# This next method will calculate the first derivate of the curve and plot them
# e.g. China

covid19_aggr_dataset.loc["China"].diff()
# Out:
# 1/22/20      NaN
# 1/23/20     95.0
# 1/24/20    277.0
# 1/25/20    486.0
# 1/26/20    669.0
#            ...
# 4/26/20      3.0
# 4/27/20      6.0
# 4/28/20     22.0
# 4/29/20      4.0
# 4/30/20     12.0
# Name: China, Length: 100, dtype: float64

# %%
# This next method will calculate the first derivate of the curve and plot them
# e.g. US

covid19_aggr_dataset.loc["US"].diff()
# Out:
# 1/22/20        NaN
# 1/23/20        0.0
# 1/24/20        1.0
# 1/25/20        0.0
# 1/26/20        3.0
#             ...
# 4/26/20    27631.0
# 4/27/20    22412.0
# 4/28/20    24385.0
# 4/29/20    27327.0
# 4/30/20    29515.0
# Name: US, Length: 100, dtype: float64

# %%
# This next method will calculate the first derivate of the curve and plot them
# e.g. China

covid19_aggr_dataset.loc["China"].diff().plot()
covid19_aggr_dataset.loc["US"].diff().plot()

# %%
# This method will return to us the maximum infection rate for China 

covid19_aggr_dataset.loc["China"].diff().max()
# Out:
# 15136.0

# %%
# This method will return to us the maximum infection rate for the US

covid19_aggr_dataset.loc["US"].diff().max()
# Out:
# 36188.0

# %%
# This method will return to us the maximum infection rate for all countries

countries = list(covid19_aggr_dataset.index)
max_inf = []
for c in countries:
    max_inf.append(covid19_aggr_dataset.loc[c].diff().max())
covid19_aggr_dataset["max_inf"] = max_inf

# %%
covid19_aggr_dataset.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
covid19_data = pd.DataFrame(covid19_aggr_dataset["max_inf"])

# %%
covid19_data.head()
# Out:
#                 max_inf
# Country/Region
# Afghanistan       232.0
# Albania            34.0
# Algeria           199.0
# Andorra            43.0
# Angola              5.0

# %%
#Create a new report called happiness report and import that csv in the notebook
happy_data = pd.read_csv("Datasets/Worldwide_happiness_report.csv")
happy_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
#Have the database remove some columns we do not need
useless_cols = ["Overall rank", "Score", "Generosity", "Perceptions of corruption"]
happy_data.drop(useless_cols, axis=1, inplace = True)

# %%
#Call back the updated report 
happy_data.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
#Set the countries as indices instead of the numbers
happy_data.set_index("Country or region", inplace=True)
happy_data.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happy_data.shape
# Out:
# (156, 4)

# %%
complete_data = covid19_data.join(happy_data, how="inner")
complete_data.head()
# Out:
#              max_inf  GDP per capita  Social support  Healthy life expectancy  \
# Afghanistan    232.0           0.350           0.517                    0.361
# Albania         34.0           0.947           0.848                    0.874
# Algeria        199.0           1.002           1.160                    0.785
# Argentina      291.0           1.092           1.432                    0.881
# Armenia        134.0           0.850           1.055                    0.815
#
#              Freedom to make life choices
# Afghanistan                         0.000
# Albania                             0.383
# Algeria                             0.086
# Argentina                           0.471
# Armenia                             0.283

# %%
complete_data.corr()
# Out:
#                                max_inf  GDP per capita  Social support  \
# max_inf                       1.000000        0.250118        0.191958
# GDP per capita                0.250118        1.000000        0.759468
# Social support                0.191958        0.759468        1.000000
# Healthy life expectancy       0.289263        0.863062        0.765286
# Freedom to make life choices  0.078196        0.394603        0.456246
#
#                               Healthy life expectancy  \
# max_inf                                      0.289263
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
#
#                               Freedom to make life choices
# max_inf                                           0.078196
# GDP per capita                                    0.394603
# ...

# %%
#Plot x as GDP per capita and y as the maximum infection rate...
x = complete_data["GDP per capita"]
y = complete_data["max_inf"]
sns.scatterplot(x, np.log(y))

# %%
#...to correctly measure the correlation between GDP and maximum infection rate
sns.regplot(x, np.log(y))

# %%
#Plot x as Social support and y as the maximum infection rate...
x = complete_data["Social support"]
y = complete_data["max_inf"]
sns.regplot(x, np.log(y))

# %%
#Plot x as Healthy life expectancy and y as the maximum infection rate...
x = complete_data["Healthy life expectancy"]
y = complete_data["max_inf"]
sns.regplot(x, np.log(y))

# %%
#Plot x as Freedom to make life choices and y as the maximum infection rate...
x = complete_data["Freedom to make life choices"]
y = complete_data["max_inf"]
sns.regplot(x, np.log(y))
